# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (2.4.1)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from seaborn) (2.4.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (2.4.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (3.6.0)

# %%
# !pip install streamlit flask
# Out:
# Requirement already satisfied: streamlit in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (1.53.0)
# Requirement already satisfied: flask in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (3.1.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=5.5 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (6.2.4)
# Requirement already satisfied: click<9,>=7.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (2.4.1)
# Requirement already satisfied: packaging>=20 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (12.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (6.33.4)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (22.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (6.5.4)
# Requirement already satisfied: jinja2 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.15.0)
# Requirement already satisfied: colorama in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.1.4)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from flask) (3.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
import pandas as pd
df = pd.read_csv("house_prices_srilanka.csv")
print("Dataset Shape (Rows, Columns):")
df.shape
# Out:
# Dataset Shape (Rows, Columns):
# (20000, 14)

# %%
print("Column Names:")
df.columns
# Out:
# Column Names:
# Index(['district', 'area', 'perch', 'bedrooms', 'bathrooms',
#        'kitchen_area_sqft', 'parking_spots', 'has_garden', 'has_ac',
#        'water_supply', 'electricity', 'floors', 'year_built', 'price_lkr'],
#       dtype='object')

# %%
df.head()
# Out:
#        district                 area  perch  bedrooms  bathrooms  \
# 0   Polonnaruwa  Polonnaruwa Central     14         5          4
# 1        Matale       Matale Central     26         7          5
# 2    Mullaitivu   Mullaitivu Central      7         3          2
# 3  Anuradhapura             New Town      2         2          2
# 4    Batticaloa      Batticaloa Town     20         5          4
#
#    kitchen_area_sqft  parking_spots  has_garden  has_ac water_supply  \
# 0                112              2       False   False   Pipe-borne
# 1                250              2        True   False         Both
# 2                 77              2        True    True         Well
# 3                 39              1        True    True         Both
# 4                117              1        True    True         Well
#
#     electricity  floors  year_built  price_lkr
# 0  Single phase       1        2022   16236332
# 1  Single phase       3        1987   33907509
# 2  Single phase       1        1988    5954312
# 3   Three phase       2        2024    5177534
# 4  Single phase       1        1995   20182409

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   district           20000 non-null  object
#  1   area               20000 non-null  object
#  2   perch              20000 non-null  int64
#  3   bedrooms           20000 non-null  int64
#  4   bathrooms          20000 non-null  int64
#  5   kitchen_area_sqft  20000 non-null  int64
#  6   parking_spots      20000 non-null  int64
#  7   has_garden         20000 non-null  bool
#  8   has_ac             20000 non-null  bool
#  9   water_supply       20000 non-null  object
#  10  electricity        20000 non-null  object
#  11  floors             20000 non-null  int64
#  12  year_built         20000 non-null  int64
#  13  price_lkr          20000 non-null  int64
# dtypes: bool(2), int64(8), object(4)
# memory usage: 1.9+ MB

# %%
target_variable = "price_lkr"
print("Target Variable:", target_variable)
# Out:
# Target Variable: price_lkr

# %%
categorical_features = [
    "district",
    "area",
    "water_supply",
    "electricity"
]

binary_features = [
    "has_garden",
    "has_ac"
]

numerical_features = [
    "perch",
    "bedrooms",
    "bathrooms",
    "kitchen_area_sqft",
    "parking_spots",
    "floors",
    "year_built"
]

print("Categorical Features:", categorical_features)
print("Binary Features:", binary_features)
print("Numerical Features:", numerical_features)
# Out:
# Categorical Features: ['district', 'area', 'water_supply', 'electricity']
# Binary Features: ['has_garden', 'has_ac']
# Numerical Features: ['perch', 'bedrooms', 'bathrooms', 'kitchen_area_sqft', 'parking_spots', 'floors', 'year_built']

# %%
feature_summary = pd.DataFrame({
    "Feature": categorical_features + binary_features + numerical_features + [target_variable],
    "Type": (
        ["Categorical"] * len(categorical_features) +
        ["Binary"] * len(binary_features) +
        ["Numerical"] * len(numerical_features) +
        ["Target"]
    )
})

feature_summary
# Out:
#               Feature         Type
# 0            district  Categorical
# 1                area  Categorical
# 2        water_supply  Categorical
# 3         electricity  Categorical
# 4          has_garden       Binary
# 5              has_ac       Binary
# 6               perch    Numerical
# 7            bedrooms    Numerical
# 8           bathrooms    Numerical
# 9   kitchen_area_sqft    Numerical
# 10      parking_spots    Numerical
# 11             floors    Numerical
# 12         year_built    Numerical
# 13          price_lkr       Target

# %%
print("Dataset Overview:")
df.info()
# Out:
# Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   district           20000 non-null  object
#  1   area               20000 non-null  object
#  2   perch              20000 non-null  int64
#  3   bedrooms           20000 non-null  int64
#  4   bathrooms          20000 non-null  int64
#  5   kitchen_area_sqft  20000 non-null  int64
#  6   parking_spots      20000 non-null  int64
#  7   has_garden         20000 non-null  bool
#  8   has_ac             20000 non-null  bool
#  9   water_supply       20000 non-null  object
#  10  electricity        20000 non-null  object
#  11  floors             20000 non-null  int64
#  12  year_built         20000 non-null  int64
#  13  price_lkr          20000 non-null  int64
# dtypes: bool(2), int64(8), object(4)
# memory usage: 1.9+ MB

# %%
print("Summary Statistics for Numerical Features:")
df.describe()
# Out:
# Summary Statistics for Numerical Features:
#               perch      bedrooms     bathrooms  kitchen_area_sqft  \
# count  20000.000000  20000.000000  20000.000000       20000.000000
# mean      11.510500      3.901600      3.171650         113.718800
# std        8.519719      1.839426      1.530883          69.801873
# min        2.000000      1.000000      1.000000          35.000000
# 25%        5.000000      2.000000      2.000000          53.000000
# 50%       10.000000      4.000000      3.000000          95.000000
# 75%       16.000000      5.000000      5.000000         161.000000
# max       80.000000      7.000000      5.000000         250.000000
#
#        parking_spots        floors    year_built     price_lkr
# count   20000.000000  20000.000000  20000.000000  2.000000e+04
# mean        1.141100      1.557150   2004.926550  1.598142e+07
# std         0.939167      0.628135     11.817353  1.338156e+07
# min         0.000000      1.000000   1985.000000  1.500000e+06
# 25%         0.000000      1.000000   1995.000000  6.591047e+06
# 50%         1.000000      1.000000   2005.000000  1.206384e+07
# 75%         2.000000      2.000000   2015.000000  2.096723e+07
# max         3.000000      3.000000   2025.000000  1.500321e+08

# %%
print("Summary Statistics for Target Variable (price_lkr):")
df["price_lkr"].describe()
# Out:
# Summary Statistics for Target Variable (price_lkr):
# count    2.000000e+04
# mean     1.598142e+07
# std      1.338156e+07
# min      1.500000e+06
# 25%      6.591047e+06
# 50%      1.206384e+07
# 75%      2.096723e+07
# max      1.500321e+08
# Name: price_lkr, dtype: float64

# %%
print("Mean House Price (LKR):", df["price_lkr"].mean())
print("Median House Price (LKR):", df["price_lkr"].median())
# Out:
# Mean House Price (LKR): 15981420.1121
# Median House Price (LKR): 12063842.0

# %%
key_features = [
    "perch",
    "bedrooms",
    "bathrooms",
    "kitchen_area_sqft",
    "year_built"
]

df[key_features].describe()
# Out:
#               perch      bedrooms     bathrooms  kitchen_area_sqft  \
# count  20000.000000  20000.000000  20000.000000       20000.000000
# mean      11.510500      3.901600      3.171650         113.718800
# std        8.519719      1.839426      1.530883          69.801873
# min        2.000000      1.000000      1.000000          35.000000
# 25%        5.000000      2.000000      2.000000          53.000000
# 50%       10.000000      4.000000      3.000000          95.000000
# 75%       16.000000      5.000000      5.000000         161.000000
# max       80.000000      7.000000      5.000000         250.000000
#
#          year_built
# count  20000.000000
# mean    2004.926550
# std       11.817353
# min     1985.000000
# 25%     1995.000000
# 50%     2005.000000
# 75%     2015.000000
# max     2025.000000

# %%
print("Missing Values Count per Column:")
df.isnull().sum()
# Out:
# Missing Values Count per Column:
# district             0
# area                 0
# perch                0
# bedrooms             0
# bathrooms            0
# kitchen_area_sqft    0
# parking_spots        0
# has_garden           0
# has_ac               0
# water_supply         0
# electricity          0
# floors               0
# year_built           0
# price_lkr            0
# dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100

print("Missing Values Percentage per Column:")
missing_percentage
# Out:
# Missing Values Percentage per Column:
# district             0.0
# area                 0.0
# perch                0.0
# bedrooms             0.0
# bathrooms            0.0
# kitchen_area_sqft    0.0
# parking_spots        0.0
# has_garden           0.0
# has_ac               0.0
# water_supply         0.0
# electricity          0.0
# floors               0.0
# year_built           0.0
# price_lkr            0.0
# dtype: float64

# %%
duplicate_count = df.duplicated().sum()

print("Number of Duplicate Rows:", duplicate_count)
# Out:
# Number of Duplicate Rows: 0

# %%
if duplicate_count > 0:
    df[df.duplicated()]
else:
    print("No duplicate records found in the dataset.")
# Out:
# No duplicate records found in the dataset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["price_lkr"], bins=50, kde=True)
plt.title("Distribution of House Prices (LKR)")
plt.xlabel("House Price (LKR)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x=df["price_lkr"])
plt.title("Boxplot of House Prices (LKR)")
plt.xlabel("House Price (LKR)")
plt.show()

# %%
numerical_features = [
    "perch",
    "bedrooms",
    "bathrooms",
    "kitchen_area_sqft",
    "parking_spots",
    "floors",
    "year_built"
]

df[numerical_features].hist(bins=20, figsize=(14, 10))
plt.suptitle("Distribution of Numerical Features", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.boxplot(data=df[numerical_features])
plt.xticks(rotation=45)
plt.title("Boxplots of Numerical Features")
plt.show()

# %%
df_clean = df.copy()
print("Working copy of dataset created.")
# Out:
# Working copy of dataset created.

# %%
df_clean.dtypes
# Out:
# district             object
# area                 object
# perch                 int64
# bedrooms              int64
# bathrooms             int64
# kitchen_area_sqft     int64
# parking_spots         int64
# has_garden             bool
# has_ac                 bool
# water_supply         object
# electricity          object
# floors                int64
# year_built            int64
# price_lkr             int64
# dtype: object

# %%
df_clean.describe()
# Out:
#               perch      bedrooms     bathrooms  kitchen_area_sqft  \
# count  20000.000000  20000.000000  20000.000000       20000.000000
# mean      11.510500      3.901600      3.171650         113.718800
# std        8.519719      1.839426      1.530883          69.801873
# min        2.000000      1.000000      1.000000          35.000000
# 25%        5.000000      2.000000      2.000000          53.000000
# 50%       10.000000      4.000000      3.000000          95.000000
# 75%       16.000000      5.000000      5.000000         161.000000
# max       80.000000      7.000000      5.000000         250.000000
#
#        parking_spots        floors    year_built     price_lkr
# count   20000.000000  20000.000000  20000.000000  2.000000e+04
# mean        1.141100      1.557150   2004.926550  1.598142e+07
# std         0.939167      0.628135     11.817353  1.338156e+07
# min         0.000000      1.000000   1985.000000  1.500000e+06
# 25%         0.000000      1.000000   1995.000000  6.591047e+06
# 50%         1.000000      1.000000   2005.000000  1.206384e+07
# 75%         2.000000      2.000000   2015.000000  2.096723e+07
# max         3.000000      3.000000   2025.000000  1.500321e+08

# %%
print("Clean Dataset Shape:", df_clean.shape)
# Out:
# Clean Dataset Shape: (20000, 14)

# %%
df_clean.to_csv("house_prices_srilanka_cleaned.csv", index=False)
print("Cleaned dataset saved successfully.")
# Out:
# Cleaned dataset saved successfully.

# %%
X = df_clean.drop("price_lkr", axis=1)
y = df_clean["price_lkr"]

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: (20000, 13)
# Target shape: (20000,)

# %%
categorical_features = [
    "district",
    "area",
    "water_supply",
    "electricity"
]

binary_features = [
    "has_garden",
    "has_ac"
]

numerical_features = [
    "perch",
    "bedrooms",
    "bathrooms",
    "kitchen_area_sqft",
    "parking_spots",
    "floors",
    "year_built"
]

print("Categorical:", categorical_features)
print("Binary:", binary_features)
print("Numerical:", numerical_features)
# Out:
# Categorical: ['district', 'area', 'water_supply', 'electricity']
# Binary: ['has_garden', 'has_ac']
# Numerical: ['perch', 'bedrooms', 'bathrooms', 'kitchen_area_sqft', 'parking_spots', 'floors', 'year_built']

# %%
X[binary_features] = X[binary_features].astype(int)

X[binary_features].head()
# Out:
#    has_garden  has_ac
# 0           0       0
# 1           1       0
# 2           1       1
# 3           1       1
# 4           1       1

# %%
X_encoded = pd.get_dummies(
    X,
    columns=categorical_features,
    drop_first=True
)

print("Encoded feature shape:", X_encoded.shape)
# Out:
# Encoded feature shape: (20000, 104)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_encoded[numerical_features] = scaler.fit_transform(
    X_encoded[numerical_features]
)

X_encoded.head()
# Out:
#       perch  bedrooms  bathrooms  kitchen_area_sqft  parking_spots  \
# 0  0.292212  0.597158   0.541106          -0.024625       0.914557
# 1  1.700744  1.684481   1.194340           1.952449       0.914557
# 2 -0.529432 -0.490165  -0.765362          -0.526056       0.914557
# 3 -1.116321 -1.033827  -0.765362          -1.070468      -0.150243
# 4  0.996478  0.597158   0.541106           0.047009      -0.150243
#
#    has_garden  has_ac    floors  year_built  district_Anuradhapura  ...  \
# 0           0       0 -0.887013    1.444814                  False  ...
# 1           1       0  2.297095   -1.517006                  False  ...
# 2           1       1 -0.887013   -1.432383                  False  ...
# 3           1       1  0.705041    1.614061                   True  ...
# 4           1       1 -0.887013   -0.840019                  False  ...
#
#    area_Unawatuna  area_Uppuveli  area_Vavuniya Central  area_Wadduwa  \
# 0           False          False                  False         False
# 1           False          False                  False         False
# 2           False          False                  False         False
# 3           False          False                  False         False
# 4           False          False                  False         False
#
#    area_Wattala  area_Weligama  area_Wellawatte  water_supply_Pipe-borne  \
# 0         False          False            False                     True
# 1         False          False            False                    False
# 2         False          False            False                    False
# 3         False          False            False                    False
# 4         False          False            False                    False
#
#    water_supply_Well  electricity_Three phase
# 0              False                    False
# 1              False                    False
# 2               True                    False
# 3              False                     True
# 4               True                    False
#
# [5 rows x 104 columns]

# %%
print("Final feature matrix shape:", X_encoded.shape)
X_encoded.info()
# Out:
# Final feature matrix shape: (20000, 104)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Columns: 104 entries, perch to electricity_Three phase
# dtypes: bool(95), float64(7), int64(2)
# memory usage: 3.2 MB

# %%
X_encoded.to_csv("X_prepared.csv", index=False)
y.to_csv("y_target.csv", index=False)

print("Encoded & scaled datasets saved successfully.")
# Out:
# Encoded & scaled datasets saved successfully.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y,
    test_size=0.2,
    random_state=42
)

# %%
print("Training features shape:", X_train.shape)
print("Testing features shape:", X_test.shape)
print("Training target shape:", y_train.shape)
print("Testing target shape:", y_test.shape)
# Out:
# Training features shape: (16000, 104)
# Testing features shape: (4000, 104)
# Training target shape: (16000,)
# Testing target shape: (4000,)

# %%
X_train.to_csv("X_train.csv", index=False)
X_test.to_csv("X_test.csv", index=False)
y_train.to_csv("y_train.csv", index=False)
y_test.to_csv("y_test.csv", index=False)

print("Train-test datasets saved successfully.")
# Out:
# Train-test datasets saved successfully.

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(X_train, y_train)

print("Linear Regression model trained successfully.")
# Out:
# Linear Regression model trained successfully.

# %%
print("Number of features used:", linear_model.coef_.shape[0])
# Out:
# Number of features used: 104

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
y_pred = linear_model.predict(X_test)

print("Predictions generated successfully.")
# Out:
# Predictions generated successfully.

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Model Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:,.2f} LKR")
print(f"Mean Squared Error (MSE): {mse:,.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:,.2f} LKR")
print(f"R² Score: {r2:.4f}")
# Out:
# Model Evaluation Metrics:
# Mean Absolute Error (MAE): 2,905,625.38 LKR
# Mean Squared Error (MSE): 21,861,773,569,369.77
# Root Mean Squared Error (RMSE): 4,675,657.55 LKR
# R² Score: 0.8771

# %%
print("Evaluation Interpretation:")
print("- MAE shows the average absolute prediction error in LKR.")
print("- RMSE penalizes larger errors more heavily.")
print("- R² indicates how much variance in house prices is explained by the model.")
# Out:
# Evaluation Interpretation:
# - MAE shows the average absolute prediction error in LKR.
# - RMSE penalizes larger errors more heavily.
# - R² indicates how much variance in house prices is explained by the model.

# %%
comparison_df = pd.DataFrame({
    "Actual Price (LKR)": y_test.values[:10],
    "Predicted Price (LKR)": y_pred[:10]
})

comparison_df
# Out:
#    Actual Price (LKR)  Predicted Price (LKR)
# 0            46231354           3.822978e+07
# 1             5513160           3.028086e+06
# 2            19637811           2.582382e+07
# 3             4803237           1.412260e+07
# 4            37051512           3.837969e+07
# 5             6903311           7.028020e+06
# 6            74905676           5.738453e+07
# 7            16452205           1.806771e+07
# 8            14115656           1.998121e+07
# 9            23137943           2.809083e+07

# %%
new_house = {
    "district": "Colombo",
    "area": "Wellawatte",
    "perch": 10,
    "bedrooms": 3,
    "bathrooms": 2,
    "kitchen_area_sqft": 90,
    "parking_spots": 1,
    "has_garden": True,
    "has_ac": True,
    "water_supply": "Pipe-borne",
    "electricity": "Three phase",
    "floors": 1,
    "year_built": 2015
}

new_house_df = pd.DataFrame([new_house])
new_house_df
# Out:
#   district        area  perch  bedrooms  bathrooms  kitchen_area_sqft  \
# 0  Colombo  Wellawatte     10         3          2                 90
#
#    parking_spots  has_garden  has_ac water_supply  electricity  floors  \
# 0              1        True    True   Pipe-borne  Three phase       1
#
#    year_built
# 0        2015

# %%
# Convert binary values
new_house_df[binary_features] = new_house_df[binary_features].astype(int)

# One-hot encode categorical features
new_house_encoded = pd.get_dummies(
    new_house_df,
    columns=categorical_features,
    drop_first=True
)

# Align columns with training data
new_house_encoded = new_house_encoded.reindex(
    columns=X_encoded.columns,
    fill_value=0
)

# Scale numerical features
new_house_encoded[numerical_features] = scaler.transform(
    new_house_encoded[numerical_features]
)

new_house_encoded
# Out:
#       perch  bedrooms  bathrooms  kitchen_area_sqft  parking_spots  \
# 0 -0.177299 -0.490165  -0.765362           -0.33981      -0.150243
#
#    has_garden  has_ac    floors  year_built  district_Anuradhapura  ...  \
# 0           1       1 -0.887013     0.85245                      0  ...
#
#    area_Unawatuna  area_Uppuveli  area_Vavuniya Central  area_Wadduwa  \
# 0               0              0                      0             0
#
#    area_Wattala  area_Weligama  area_Wellawatte  water_supply_Pipe-borne  \
# 0             0              0                0                        0
#
#    water_supply_Well  electricity_Three phase
# 0                  0                        0
#
# [1 rows x 104 columns]

# %%
predicted_price = linear_model.predict(new_house_encoded)

print(f"Predicted House Price: {predicted_price[0]:,.2f} LKR")
# Out:
# Predicted House Price: 15,003,341.79 LKR

# %%
import pickle

# Save model
with open("model.pkl", "wb") as f:
    pickle.dump(linear_model, f)

# Save scaler
with open("scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)

# Save column order
with open("X_columns.pkl", "wb") as f:
    pickle.dump(X_encoded.columns, f)

print("Model, scaler, and columns saved successfully.")
# Out:
# Model, scaler, and columns saved successfully.

# %%
# !pip install scikit-learn pandas numpy
# Out:
# Requirement already satisfied: scikit-learn in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (1.8.0)
# Requirement already satisfied: pandas in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (2.4.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\veenu\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
